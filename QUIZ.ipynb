# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Backing off send_request(...) for 0.5s (requests.exceptions.ConnectionError: HTTPSConnectionPool(host='api.segment.io', port=443): Max retries exceeded with url: /v1/batch (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001C39DE3BD00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')))
# Backing off send_request(...) for 0.5s (requests.exceptions.ConnectionError: HTTPSConnectionPool(host='api.segment.io', port=443): Max retries exceeded with url: /v1/batch (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001C39DE551F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')))
# ...

# %%
vee = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding='latin-1')
vee.to_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', index=False)
vee.head(3)
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
#
#                          Element             Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes     1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity      1000 tonnes      0.0      0.0      0.0
# 2  Food supply (kcal/capita/day)  kcal/capita/day   3377.0   3379.0   3372.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0
# 2   3341.0   3322.0

# %%
#Question 11
vee.groupby('Item')['Y2014'].sum()
# Out:
# Item
# Alcohol, Non-Food        2403.00
# Alcoholic Beverages    102410.11
# Animal Products         11935.65
# Animal fats            209460.54
# Apples and products      9499.23
#                          ...
# Vegetables, Other      155038.96
# Vegetal Products       107145.19
# Wheat and products     232670.13
# Wine                     4497.36
# Yams                   200396.96
# Name: Y2014, Length: 119, dtype: float64

# %%
vee.groupby('Item')['Y2017'].sum()
# Out:
# Item
# Alcohol, Non-Food        2348.00
# Alcoholic Beverages     95581.06
# Animal Products         11547.65
# Animal fats            269617.53
# Apples and products     10198.90
#                          ...
# Vegetables, Other      157752.59
# Vegetal Products       107655.20
# Wheat and products     240047.62
# Wine                     4178.02
# Yams                   229174.59
# Name: Y2017, Length: 119, dtype: float64

# %%
vee.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#Question 12
vee.groupby('Item')['Y2015'].describe().sum()
# Out:
# count     59395.000000
# mean      25481.939954
# std       80463.005497
# min      -17548.540000
# 25%         125.160000
# 50%         591.730000
# 75%       21885.872500
# max      808183.970000
# dtype: float64

# %%
vee[['Y2016']].isnull().sum()
# Out:
# Y2016    1535
# dtype: int64

# %%
vee.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
vee.isnull().sum().describe()
# Out:
# count      12.000000
# mean      634.500000
# std       784.885574
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%      1513.250000
# max      1589.000000
# dtype: float64

# %%
#Question 
ve2=vee.groupby('Element').sum()
ve2
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
ve2=vee.groupby('Element').sum()
ve2.sort_values(by ="Element").head(12)
# Out:
#                                      Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                708993   14197445      28068795
# Export Quantity                         599910   11840553      26026133
# Fat supply quantity (g/capita/day)      675050   13535000       3435732
# Feed                                    176272    3538507       7282199
# Food                                    663295   13285035      25406622
# Food supply (kcal/capita/day)           674057   13511060       3329296
# Food supply quantity (kg/capita/yr)     658446   13185401       3163725
# Import Quantity                         688174   13795966      28834929
# Losses                                  274353    5424803      10292107
# Other uses (non-food)                   235554    4729749       8926728
# Processing                              271940    5350416      10313310
# Production                              526751   10450053      21388191
#
# ...

# %%
#Question 15
#Y2017 has the highest import quality
ve2.loc['Import Quantity'][0:]
# Out:
# Area Code         688174.00
# Item Code       13795966.00
# Element Code    28834929.00
# Y2014             274144.48
# Y2015             267018.46
# Y2016             286582.78
# Y2017             294559.09
# Y2018             287997.09
# Name: Import Quantity, dtype: float64

# %%
# vee.groupby('Item')['Y2014'].sum()

# %%
#question 16
ve3=vee.groupby('Element')['Y2014'].sum()
ve3.loc['Production']
# Out:
# 1931287.75

# %%
#Question17
ve4=vee.groupby('Element')['Y2018'].sum()
ve4
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
ve4.max()#The highest Quantity is Domestic supply quantity
# Out:
# 2161192.1

# %%
# #Question 18
# ve4.sort_values(by = "Element")
# # ve2.sort_values(by ="Element", ).head(12)
ve4=vee.groupby('Element')['Y2018'].sum()
ve4
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
vee.head(3)
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
#
#                          Element             Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes     1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity      1000 tonnes      0.0      0.0      0.0
# 2  Food supply (kcal/capita/day)  kcal/capita/day   3377.0   3379.0   3372.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0
# 2   3341.0   3322.0

# %%
##Question 19
ve6= vee.groupby('Area')['Y2018'].count().head(5)
ve6
# Out:
# Area
# Algeria         1298
# Angola          1396
# Benin           1252
# Botswana        1361
# Burkina Faso    1373
# Name: Y2018, dtype: int64

# %%
# ve6['Algeria'].()

# %%
vee.head(2)
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
# 1          4  Algeria       2501  Population          5301
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity   1000 tonnes      0.0      0.0      0.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0

# %%
vee.groupby('Area').count().head(5)
# Out:
#               Area Code  Item Code  Item  Element Code  Element  Unit  Y2014  \
# Area
# Algeria            1313       1313  1313          1313     1313  1313   1261
# Angola             1424       1424  1424          1424     1424  1424   1378
# Benin              1285       1285  1285          1285     1285  1285   1250
# Botswana           1378       1378  1378          1378     1378  1378   1361
# Burkina Faso       1409       1409  1409          1409     1409  1409   1382
#
#               Y2015  Y2016  Y2017  Y2018
# Area
# Algeria        1268   1274   1279   1298
# Angola         1378   1388   1407   1396
# Benin          1260   1257   1253   1252
# Botswana       1369   1365   1368   1361
# Burkina Faso   1372   1392   1383   1373

# %%
ve10=vee.groupby('Area')['Y2018'].sum()
ve10.count()
# Out:
# 49

# %%
##Question 20
#############
ve8= vee.groupby('Area')['Area Code'].count()
ve8
# Out:
# Area
# Algeria                         1313
# Angola                          1424
# Benin                           1285
# Botswana                        1378
# Burkina Faso                    1409
# Cabo Verde                      1260
# Cameroon                        1460
# Central African Republic        1344
# Chad                            1343
# Comoros                           45
# Congo                           1413
# CÃÂÃÂÃÂÃÂ´te d'Ivoire    1467
# Djibouti                        1095
# Egypt                           1488
# Eswatini                        1284
# Ethiopia                        1447
# Ethiopia PDR                      39
# Gabon                           1245
# Gambia                          1168
# Ghana                           1354
# Guinea                          1410
# Guinea-Bissau                   1128
# Kenya                           1560
# Lesotho                         1150
# Liberia                         1206
# ...

# %%
ve8.isnull().count()
# Out:
# 49
# Backing off send_request(...) for 11.4s (requests.exceptions.ConnectionError: HTTPSConnectionPool(host='api.segment.io', port=443): Max retries exceeded with url: /v1/batch (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001C3A66B1C10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')))
# Backing off send_request(...) for 15.8s (requests.exceptions.ConnectionError: HTTPSConnectionPool(host='api.segment.io', port=443): Max retries exceeded with url: /v1/batch (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001C3A66B1B50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')))
# ...
